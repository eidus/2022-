# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### 현재 디렉토리 확인

# %%
print(os.getcwd())
# Out:
# c:\Users\rladb\Documents\R_review

# %% [markdown]
# ### 운동처방데이터

# %%
p1 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202008.csv")
p2 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202009.csv")
p3 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202010.csv")
p4 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202011.csv")
p5 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202012.csv")
p6 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202101.csv")
p7 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202102.csv")
p8 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202103.csv")
p9 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202104.csv")
p10 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202105.csv")
p11 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202106.csv")
p12 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202107.csv")
p13 = pd.read_csv("C:\\Users\\rladb\\Documents\\R_review\\phisical\\KS_DSPSN_FTNESS_MESURE_ACCTO_MVM_PRSCRPTN_LIST_202108.csv")

# %%
dp_list = [p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13]
all_prscrptn = pd.concat(dp_list,ignore_index = True)
all_prscrptn2 = pd.concat(dp_list)

# %% [markdown]
# 1 측정기준을 가지고 이 나이대, 성별 ,등급, 유형별 처방은 알 수 있으나,
# 2 체력측정을 고려

# %%
all_prscrptn.head(30)
# Out:
#     MESURE_TME CNTER_NM AGE_FLAG_NM MESURE_PLACE_FLAG_NM  MESURE_AGE_CO  \
# 0            4       대전          성인                   출장             37
# 1            4       대전          성인                   출장             25
# 2            5       대전          성인                   출장             50
# 3            5       대전          성인                   출장             25
# 4            5       대전          성인                   출장             28
# 5            5       대전          성인                   출장             24
# 6            5       대전          성인                   출장             26
# 7            4       대전          성인                   출장             32
# 8            3       대전          성인                   출장             22
# 9            2       대전          성인                   출장             31
# 10           4       대전          성인                   출장             49
# 11           4       대전          성인                   출장             29
# ...

# %%
all_prscrptn[]

# %%
all_prscrptn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2980 entries, 0 to 2979
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MESURE_TME            2980 non-null   int64
#  1   CNTER_NM              2980 non-null   object
#  2   AGE_FLAG_NM           2980 non-null   object
#  3   MESURE_PLACE_FLAG_NM  2980 non-null   object
#  4   MESURE_AGE_CO         2980 non-null   int64
#  5   INPT_FLAG_NM          2980 non-null   object
#  6   MESURE_DE             2980 non-null   int64
#  7   SEXDSTN_FLAG_CD       2980 non-null   object
#  8   TROBL_TY_NM           2980 non-null   object
#  9   TROBL_DETAIL_NM       211 non-null    object
#  10  TROBL_GRAD_NM         2980 non-null   object
#  11  MVM_PRSCRPTN_CN       2980 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 279.5+ KB

# %%
all_prscrptn.describe()
# Out:
#         MESURE_TME  MESURE_AGE_CO     MESURE_DE
# count  2980.000000    2980.000000  2.980000e+03
# mean      2.222483      33.405034  2.020858e+07
# std       1.936859      15.639830  3.803452e+03
# min       0.000000      13.000000  2.020080e+07
# 25%       1.000000      22.000000  2.021022e+07
# 50%       1.000000      29.000000  2.021042e+07
# 75%       3.000000      43.000000  2.021061e+07
# max      11.000000      91.000000  2.021081e+07

# %%
all_prscrptn.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'MESURE_TME'}>,
#         <AxesSubplot:title={'center':'MESURE_AGE_CO'}>],
#        [<AxesSubplot:title={'center':'MESURE_DE'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
all_prscrptn.to_csv('Collect_prscrptn.csv')
